# %%
import requests

# %%
response = requests.get('https://lalafo.kg/bishkek/avtomobili-s-probegom/prodazha-avtomobiley/other-cars/electric?currency=USD&price[from]=1000')

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="ru-RU"><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="google" content="notranslate"/><link rel="icon" type="image/png" sizes="32x32" href="/favicons/logos/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="/favicons/logos/favicon-16x16.png"/><link rel="apple-touch-icon" sizes="76x76" href="/favicons/apple-touch-icon.png"/><link rel="manifest" href="/site.webmanifest"/><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><link rel="stylesheet" href="/styles/fonts.css"/><noscript><img alt="fb pixel" height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=399844810646840&amp;ev=PageView&amp;noscript=1"/></noscript><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, maximum-scale=1"/><script async="" id="fb-pixel">\n        !function(f,b,e,v,n,t,s)\n        {if(f.fbq)return;n=f.fbq
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru-RU">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="notranslate" name="google"/>
#   <link href="/favicons/logos/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicons/logos/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <link href="/styles/fonts.css" rel="stylesheet"/>
#   <noscript>
#    <img alt="fb pixel" height="1" src="https://www.facebook.com/tr?id=399844810646840&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no, maximum-scale=1" name="viewport"/>
# ...

# %%
elements_price = soup.find_all('p', class_='adTile-price international-price')
price = [element.text for element in elements_price]

# %%
price
# Out:
# []

# %%
description_tag = soup.find_all('a', class_='adTile-title')
description= [element.text for element in description_tag]

# %%
description
# Out:
# ['Китайский электромобиль BAIC EC3 (Б/У) Запас хода: 300 км Год выпуска',
#  'Китайский электромобиль Велтмейстер EX5 400 (Б/У) Запас хода: 400 км',
#  '️ Weltmeister EX5 на русском языке! Максимальная комплектация! В',
#  'Марка Элекромобиля Honqqi Модель: E-HS63 Год выпуска:2019 Тип',
#  'Китайский электромобиль BAIC EC3 (Б/У) Запас хода: 300 км Год выпуска',
#  'Китайский электромобиль Велтмейстер EX5 400 (Б/У) Запас хода: 400 км',
#  'Продаю Электромобиль skyworth ev6 Год:2022 руль: левый кпп: автомат',
#  'Weltmeister EX5 2019г 44000км пробег 400км запас хода 218 л.с Только',
#  'Weltmeister Ex-5 PRO Запас хода 465км Ёмкость батареи 59.5 кв Пробег',
#  'Golf car Размеры: 2400 х 1200 х 1620 мм. Дорожный просвет: 10 дюймов',
#  'Электромобиль! Запас хода 300км 30сом полный заряд! 2019год свежий!',
#  'ЭЛЕКТРОКАР ЭЛЕКТРОМОБИЛЬ КИТАЕЦ Weltmeister ex5 400 Пробег 22000км',
#  'Продаю Электромобиль. Прибыл в январе 2023 года. Возможен обмен на',
# ...

# %%
def car_brand(text):
  latin_sentence = ''
  for element_index, elements in enumerate(text):
    for abc in elements:
      if  65 <= ord(abc) <= 90 or 97 <= ord(abc) <= 122:

# %%
car_name = []
car_status = []
car_range = []
for element in description:

# %%
lst = [1,2,3,4]
sum(lst)
# Out:
# 10

# %%
text = 'Китайский электромобиль BAIC EC3 (Б/У) Запас хода: 300 км Год выпуска'
latin_sentence_index = []
for element_index, element in enumerate(text.split()):
  for abc in element:
    if ('A' <= abc <= 'Z') or ('a' <= abc <= 'z'):
      latin_sentence_index.append(element_index)
      break

# %%
car_brand
# Out:
# [2, 3]

# %%
 q
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-5a7a761d5ac9> in <cell line: 2>()
#       1 lst = ['f' , 'j']
# ----> 2 sum(lst)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
